# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyasnj/machine-learning/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
fn=pd.read_csv('FakeNewsNet[2].csv')

# %%
fn.head()
# Out:
#                                                title  \
# 0  Kandi Burruss Explodes Over Rape Accusation on...
# 1  People's Choice Awards 2018: The best red carp...
# 2  Sophia Bush Sends Sweet Birthday Message to 'O...
# 3  Colombian singer Maluma sparks rumours of inap...
# 4  Gossip Girl 10 Years Later: How Upper East Sid...
#
#                                             news_url        source_domain  \
# 0  http://toofab.com/2017/05/08/real-housewives-a...           toofab.com
# 1  https://www.today.com/style/see-people-s-choic...        www.today.com
# 2  https://www.etonline.com/news/220806_sophia_bu...     www.etonline.com
# 3  https://www.dailymail.co.uk/news/article-33655...  www.dailymail.co.uk
# 4  https://www.zerchoo.com/entertainment/gossip-g...      www.zerchoo.com
#
#    tweet_num  real
# 0         42     1
# 1          0     1
# 2         63     1
# 3         20     1
# 4         38     1

# %%
fn.shape
# Out:
# (23196, 5)

# %%
fn.tail()
# Out:
#                                                    title  \
# 23191  Pippa Middleton wedding: In case you missed it...
# 23192  Zayn Malik & Gigi Hadid’s Shocking Split: Why ...
# 23193  Jessica Chastain Recalls the Moment Her Mother...
# 23194  Tristan Thompson Feels "Dumped" After Khloé Ka...
# 23195  Kelly Clarkson Performs a Medley of Kendrick L...
#
#                                                 news_url  \
# 23191  https://www.express.co.uk/news/royal/807049/pi...
# 23192  hollywoodlife.com/2018/03/13/zayn-malik-gigi-h...
# 23193  http://www.justjared.com/2018/01/17/jessica-ch...
# 23194  www.intouchweekly.com/posts/tristan-thompson-f...
# 23195  https://www.billboard.com/articles/news/bbma/8...
#
#                source_domain  tweet_num  real
# 23191      www.express.co.uk         52     1
# 23192      hollywoodlife.com          7     0
# 23193      www.justjared.com         26     1
# 23194  www.intouchweekly.com         24     0
# ...

# %%
fn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23196 entries, 0 to 23195
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          23196 non-null  object
#  1   news_url       22866 non-null  object
#  2   source_domain  22866 non-null  object
#  3   tweet_num      23196 non-null  int64
#  4   real           23196 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 906.2+ KB

# %%
fn.isnull().sum()
# Out:
# title              0
# news_url         330
# source_domain    330
# tweet_num          0
# real               0
# dtype: int64

# %%
fn.notnull().sum()
# Out:
# title            23196
# news_url         22866
# source_domain    22866
# tweet_num        23196
# real             23196
# dtype: int64

# %%
fn.value_counts('real')
# Out:
# real
# 1    17441
# 0     5755
# Name: count, dtype: int64

# %%
fn.groupby('real').mean(numeric_only=True)
# Out:
#        tweet_num
# real
# 0     132.693484
# 1      74.525027

# %%
fn.count()
# Out:
# title            23196
# news_url         22866
# source_domain    22866
# tweet_num        23196
# real             23196
# dtype: int64

# %%
fn.mean(numeric_only=True)
# Out:
# tweet_num    88.956803
# real          0.751897
# dtype: float64

# %%
fn.std(numeric_only=True)
# Out:
# tweet_num    488.694592
# real           0.431921
# dtype: float64

# %%
fn.min(numeric_only=True)
# Out:
# tweet_num    0
# real         0
# dtype: int64

# %%
fn.max(numeric_only=True)
# Out:
# tweet_num    29060
# real             1
# dtype: int64

# %%
fn.describe()
# Out:
#           tweet_num          real
# count  23196.000000  23196.000000
# mean      88.956803      0.751897
# std      488.694592      0.431921
# min        0.000000      0.000000
# 25%       11.000000      1.000000
# 50%       37.000000      1.000000
# 75%       65.000000      1.000000
# max    29060.000000      1.000000

# %%
fn['tweet_num']
# Out:
# 0        42
# 1         0
# 2        63
# 3        20
# 4        38
#          ..
# 23191    52
# 23192     7
# 23193    26
# 23194    24
# 23195    85
# Name: tweet_num, Length: 23196, dtype: int64

# %%
fn.loc[::2]
# Out:
#                                                    title  \
# 0      Kandi Burruss Explodes Over Rape Accusation on...
# 2      Sophia Bush Sends Sweet Birthday Message to 'O...
# 4      Gossip Girl 10 Years Later: How Upper East Sid...
# 6      Broward County Sheriff Fired For Lying About P...
# 8      Mindy Kaling makes first post-baby appearance ...
# ...                                                  ...
# 23186  'Real Housewives of New York' teases drama in ...
# 23188  Caitlyn Jenner considering ‘de-transitioning’ ...
# 23190  See 'Love Actually' Sequel Clip for Red Nose D...
# 23192  Zayn Malik & Gigi Hadid’s Shocking Split: Why ...
# 23194  Tristan Thompson Feels "Dumped" After Khloé Ka...
#
#                                                 news_url  \
# 0      http://toofab.com/2017/05/08/real-housewives-a...
# 2      https://www.etonline.com/news/220806_sophia_bu...
# 4      https://www.zerchoo.com/entertainment/gossip-g...
# ...

# %%
fn.loc[:,"real"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 23191    1
# 23192    0
# 23193    1
# 23194    0
# 23195    1
# Name: real, Length: 23196, dtype: int64

# %%
fn.iloc[0:3]
# Out:
#                                                title  \
# 0  Kandi Burruss Explodes Over Rape Accusation on...
# 1  People's Choice Awards 2018: The best red carp...
# 2  Sophia Bush Sends Sweet Birthday Message to 'O...
#
#                                             news_url     source_domain  \
# 0  http://toofab.com/2017/05/08/real-housewives-a...        toofab.com
# 1  https://www.today.com/style/see-people-s-choic...     www.today.com
# 2  https://www.etonline.com/news/220806_sophia_bu...  www.etonline.com
#
#    tweet_num  real
# 0         42     1
# 1          0     1
# 2         63     1

# %%
fn.iloc[0:6,0:2]
# Out:
#                                                title  \
# 0  Kandi Burruss Explodes Over Rape Accusation on...
# 1  People's Choice Awards 2018: The best red carp...
# 2  Sophia Bush Sends Sweet Birthday Message to 'O...
# 3  Colombian singer Maluma sparks rumours of inap...
# 4  Gossip Girl 10 Years Later: How Upper East Sid...
# 5  Gwen Stefani Got Dumped by Blake Shelton Over ...
#
#                                             news_url
# 0  http://toofab.com/2017/05/08/real-housewives-a...
# 1  https://www.today.com/style/see-people-s-choic...
# 2  https://www.etonline.com/news/220806_sophia_bu...
# 3  https://www.dailymail.co.uk/news/article-33655...
# 4  https://www.zerchoo.com/entertainment/gossip-g...
# 5  www.intouchweekly.com/posts/gwen-stefani-dumpe...

# %%
fn.fillna(0)
# Out:
#                                                    title  \
# 0      Kandi Burruss Explodes Over Rape Accusation on...
# 1      People's Choice Awards 2018: The best red carp...
# 2      Sophia Bush Sends Sweet Birthday Message to 'O...
# 3      Colombian singer Maluma sparks rumours of inap...
# 4      Gossip Girl 10 Years Later: How Upper East Sid...
# ...                                                  ...
# 23191  Pippa Middleton wedding: In case you missed it...
# 23192  Zayn Malik & Gigi Hadid’s Shocking Split: Why ...
# 23193  Jessica Chastain Recalls the Moment Her Mother...
# 23194  Tristan Thompson Feels "Dumped" After Khloé Ka...
# 23195  Kelly Clarkson Performs a Medley of Kendrick L...
#
#                                                 news_url  \
# 0      http://toofab.com/2017/05/08/real-housewives-a...
# 1      https://www.today.com/style/see-people-s-choic...
# 2      https://www.etonline.com/news/220806_sophia_bu...
# ...

# %%
fn.drop(index=0,axis=0)
# Out:
#                                                    title  \
# 1      People's Choice Awards 2018: The best red carp...
# 2      Sophia Bush Sends Sweet Birthday Message to 'O...
# 3      Colombian singer Maluma sparks rumours of inap...
# 4      Gossip Girl 10 Years Later: How Upper East Sid...
# 5      Gwen Stefani Got Dumped by Blake Shelton Over ...
# ...                                                  ...
# 23191  Pippa Middleton wedding: In case you missed it...
# 23192  Zayn Malik & Gigi Hadid’s Shocking Split: Why ...
# 23193  Jessica Chastain Recalls the Moment Her Mother...
# 23194  Tristan Thompson Feels "Dumped" After Khloé Ka...
# 23195  Kelly Clarkson Performs a Medley of Kendrick L...
#
#                                                 news_url  \
# 1      https://www.today.com/style/see-people-s-choic...
# 2      https://www.etonline.com/news/220806_sophia_bu...
# 3      https://www.dailymail.co.uk/news/article-33655...
# ...

# %%
fn.drop(columns="real",index=1)
# Out:
#                                                    title  \
# 0      Kandi Burruss Explodes Over Rape Accusation on...
# 2      Sophia Bush Sends Sweet Birthday Message to 'O...
# 3      Colombian singer Maluma sparks rumours of inap...
# 4      Gossip Girl 10 Years Later: How Upper East Sid...
# 5      Gwen Stefani Got Dumped by Blake Shelton Over ...
# ...                                                  ...
# 23191  Pippa Middleton wedding: In case you missed it...
# 23192  Zayn Malik & Gigi Hadid’s Shocking Split: Why ...
# 23193  Jessica Chastain Recalls the Moment Her Mother...
# 23194  Tristan Thompson Feels "Dumped" After Khloé Ka...
# 23195  Kelly Clarkson Performs a Medley of Kendrick L...
#
#                                                 news_url  \
# 0      http://toofab.com/2017/05/08/real-housewives-a...
# 2      https://www.etonline.com/news/220806_sophia_bu...
# 3      https://www.dailymail.co.uk/news/article-33655...
# ...
